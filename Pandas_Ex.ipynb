# %%
import pandas as pd

# %%
df = pd.read_csv('./data/rentals.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8111 entries, 0 to 8110
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              8111 non-null   int64
#  1   latitude        8111 non-null   float64
#  2   longitude       8111 non-null   float64
#  3   property_type   8111 non-null   object
#  4   room_type       8111 non-null   object
#  5   bathrooms       8099 non-null   float64
#  6   bedrooms        8107 non-null   float64
#  7   minimum_nights  8111 non-null   int64
#  8   price           8111 non-null   object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 570.4+ KB

# %%
df.isna().sum()
# Out:
# id                 0
# latitude           0
# longitude          0
# property_type      0
# room_type          0
# bathrooms         12
# bedrooms           4
# minimum_nights     0
# price              0
# dtype: int64

# %%
df[['bathrooms', 'bedrooms']].median()
# Out:
# bathrooms    1.0
# bedrooms     1.0
# dtype: float64

# %%
df[['bathrooms', 'bedrooms']]=df[['bathrooms', 'bedrooms']].fillna(df[['bathrooms', 'bedrooms']].median())

# %%
df['price'] = df['price'].str.strip()
df['price'] = df['price'].str.replace('$','', regex = False)
df['price'] = df['price'].str.replace(',','', regex = False)
df['price'] = df['price'].astype(float)

# %%
df.describe()
# Out:
#                  id     latitude    longitude    bathrooms     bedrooms  \
# count  8.111000e+03  8111.000000  8111.000000  8111.000000  8111.000000
# mean   2.024561e+07    37.766054  -122.430107     1.395389     1.345703
# std    1.228565e+07     0.022937     0.026967     0.922655     0.925102
# min    9.580000e+02    37.704630  -122.513060     0.000000     0.000000
# 25%    8.905668e+06    37.751450  -122.442830     1.000000     1.000000
# 50%    2.161057e+07    37.769150  -122.424650     1.000000     1.000000
# 75%    3.120025e+07    37.785670  -122.410615     1.500000     2.000000
# max    3.935418e+07    37.828790  -122.368570    14.000000    14.000000
#
#        minimum_nights         price
# count    8.111000e+03   8111.000000
# mean     1.234526e+04    225.407101
# std      1.110357e+06    412.253039
# min      1.000000e+00      0.000000
# 25%      2.000000e+00    100.000000
# 50%      4.000000e+00    150.000000
# 75%      3.000000e+01    240.000000
# max      1.000000e+08  10000.000000

# %%
idx_loc = df[df['minimum_nights']>365].index
df = df.drop(idx_loc, axis = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8092 entries, 0 to 8110
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              8092 non-null   int64
#  1   latitude        8092 non-null   float64
#  2   longitude       8092 non-null   float64
#  3   property_type   8092 non-null   object
#  4   room_type       8092 non-null   object
#  5   bathrooms       8092 non-null   float64
#  6   bedrooms        8092 non-null   float64
#  7   minimum_nights  8092 non-null   int64
#  8   price           8092 non-null   float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 632.2+ KB

# %%
df.describe()
# Out:
#                  id     latitude    longitude    bathrooms     bedrooms  \
# count  8.092000e+03  8092.000000  8092.000000  8092.000000  8092.000000
# mean   2.026915e+07    37.766016  -122.430128     1.395885     1.346515
# std    1.227070e+07     0.022939     0.026979     0.923239     0.926036
# min    9.580000e+02    37.704630  -122.513060     0.000000     0.000000
# 25%    8.937525e+06    37.751430  -122.442870     1.000000     1.000000
# 50%    2.162208e+07    37.769100  -122.424670     1.000000     1.000000
# 75%    3.120736e+07    37.785600  -122.410620     1.500000     2.000000
# max    3.935418e+07    37.828790  -122.368570    14.000000    14.000000
#
#        minimum_nights         price
# count     8092.000000   8092.000000
# mean        16.067474    225.307588
# std         22.232230    411.320555
# min          1.000000      0.000000
# 25%          2.000000    100.000000
# 50%          4.000000    150.000000
# 75%         30.000000    240.000000
# max        365.000000  10000.000000

# %%
p_group = df.groupby('property_type')[['price']].mean()
p_group.sort_values(by = 'price')
# Out:
#                          price
# property_type
# Camper/RV            20.000000
# Hut                  69.000000
# Hostel               71.511628
# Castle              101.000000
# Dome house          135.000000
# Cabin               151.333333
# In-law              155.000000
# Bed and breakfast   155.372093
# Aparthotel          159.317073
# Guest suite         160.956672
# Bungalow            169.764706
# Tiny house          170.000000
# Other               173.500000
# Apartment           204.075186
# Guesthouse          204.658537
# Cottage             219.583333
# House               224.258539
# Serviced apartment  226.355372
# Hotel               265.490446
# Condominium         273.364759
# Loft                277.863636
# Townhouse           292.528169
# Earth house         354.500000
# Villa               379.200000
# Boutique hotel      460.460674
# Resort              484.000000

# %%
df['room_type'].value_counts()
# Out:
# Entire home/apt    4766
# Private room       2884
# Shared room         235
# Hotel room          207
# Name: room_type, dtype: int64
