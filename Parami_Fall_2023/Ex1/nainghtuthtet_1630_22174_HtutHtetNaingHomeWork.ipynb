# %% [markdown]
# <a href="https://colab.research.google.com/github/myothida/PythonProgramming/blob/main/Ex1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# This section introduces the Python Programming uisng Colab. Follow the instructions and complete the exercises.

# %% [markdown]
# # Ex 1 : Check Version

# %% [markdown]
# Using the below cell, Import the required library and check the version of the python in your environment.

# %%
import sys
sys.version
# Out:
# '3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]'

# %%
import numpy as np
np.__version__
# Out:
# '1.23.5'

# %%
import pandas as pd
(pd.__version__)
# Out:
# '1.5.3'

# %% [markdown]
# # Ex2 : Convert Currency.

# %% [markdown]
# Write a program that asks the user for the amount in usd and converts it to British pounds. The exchange rate is from usd to BP is given as 0.82

# %%
usd_amount = input ("Enter the amount in USD: ")
bp_amount = int(usd_amount) *0.82
print("{} usd is equivalent to {} british pound".format(usd_amount, bp_amount))
# Out:
# Enter the amount in USD: 1500
# 1500 usd is equivalent to 1230.0 british pound

# %%
US_Dollar_Amount = input ("Enter the amount in USD: ")
BP_Amount = int(US_Dollar_Amount) *0.82
print("{} US Dollar is equivalent to {} British Pound".format(US_Dollar_Amount, BP_Amount))
# Out:
# Enter the amount in USD: 2
# 2 US Dollar is equivalent to 1.64 British Pound

# %% [markdown]
# # Ex 3: Temperature Converter

# %% [markdown]
# Write a program that convert temperature in Feranhite to celsius.

# %%
a = input("Temperature to Change into Celcius (Fill in Feranhite): ")
b = 5 / 9 * (int(a) - 32)
b
print("{} Temperature Feranhite is equal to {} Temperature Celsius".format(a,b))
# Out:
# Temperature to Change into Celcius (Fill in Feranhite): 20
# 20 Temperature Feranhite is equal to -6.666666666666667 Temperature Celsius

# %% [markdown]
# # Ex 4: Daily Maths

# %% [markdown]
# You are working in a retail shop. Write a program that computes the total cost for a customer that bought 3 differnt types of fruits : apple, orange, mango. Ask the user to enter the quantity and price for each type.

# %%
#Price of each item
a = input ("Price of Apple: ")
o = input ("Price of Orange: ")
m = input ("Price of Mango: ")

#Quantity of each item
qa = input ("Quantity of Apple: ")
qo = input ("Qunatity of Orange: ")
qm = input ("Quantity of Mango: ")

Cost_for_Apple = int(a) * int(qa)
Cost_for_Orange = int(o) * int(qo)
Cost_for_Mango = int (m) * int(qm)
TotalC = int(Cost_for_Apple) + int(Cost_for_Orange) + int(Cost_for_Mango)
TotalC

print(" ")
print("Cost for Apple=" + str(Cost_for_Apple))
print("Cost for Orange=" + str(Cost_for_Orange))
print("Cost for Mango=" + str(Cost_for_Mango))

print(" ")
print("Total Cost = " + str(TotalC))
print("Note: To calculate the total price, the customer has to put values by himself.")
print("For Payment: The customer may choose to pay via Kpay or Cash as intended.")
# Out:
# Price of Apple: 5
# Price of Orange: 5
# Price of Mango: 5
# Quantity of Apple: 5
# Qunatity of Orange: 5
# Quantity of Mango: 5
#
# Cost for Apple=25
# Cost for Orange=25
# Cost for Mango=25
#
# Total Cost = 75
# Note: To calculate the total price, the customer has to put values by himself.
# For Payment: The customer may choose to pay via Kpay or Cash as intended.

# %% [markdown]
# # Ex 5 : Greeting

# %% [markdown]
# Write a program to greet the customer who provides the user name. Your program should ask the name of the customer and print "Hello + customer name"

# %%
name = input ("Your Name: ")
greeting = "Hello," + (" ") + str(name) + ("!") + (" ") + ("Nice to meet you. Welcome to our shop.")
print(str(greeting))
# Out:
# Your Name: Htut
# Hello, Htut! Nice to meet you. Welcome to our shop.
